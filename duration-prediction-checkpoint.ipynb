# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
df = pd.read_parquet('/Users/zulikahlatief/Desktop/personal/taxi-duration-prediction-web-service/data/green_tripdata_2022-01.parquet')

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df = df[(df.duration >= 1) & (df.duration <= 60)]

categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 7.735793552150638

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()
# Out:
# /var/folders/lx/m3fc9q_96bq7m1wyg7w6s1pc0000gn/T/ipykernel_5864/1672306066.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction')
# /var/folders/lx/m3fc9q_96bq7m1wyg7w6s1pc0000gn/T/ipykernel_5864/1672306066.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, label='actual')

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('/Users/zulikahlatief/Desktop/personal/taxi-duration-prediction-web-service/data/green_tripdata_2022-01.parquet')
df_val = read_dataframe('/Users/zulikahlatief/Desktop/personal/taxi-duration-prediction-web-service/data/green_tripdata_2022-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (59603, 66097)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 6.90139679473241

# %%
with open('reports/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
alpha = 0.1
lr = Lasso(alpha)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)
rmse = mean_squared_error(y_val, y_pred, squared=False)

# %%
rmse
# Out:
# 9.930283098543175

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    booster = xgb.train(
        params=params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )
    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=2,
    trials=Trials()
)
# Out:
# [17:35:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:13.32455
# [1]	validation-rmse:10.56704
# [2]	validation-rmse:8.77074
# [3]	validation-rmse:7.64520
# [4]	validation-rmse:6.96657
# [5]	validation-rmse:6.56435
# [6]	validation-rmse:6.31657
# [7]	validation-rmse:6.16921
# [8]	validation-rmse:6.08078
# [9]	validation-rmse:6.02255
# [10]	validation-rmse:5.98528
# [11]	validation-rmse:5.95589
# [12]	validation-rmse:5.93622
# [13]	validation-rmse:5.92320
# [14]	validation-rmse:5.91438
# [15]	validation-rmse:5.90859
# [16]	validation-rmse:5.90467
# [17]	validation-rmse:5.90137
# [18]	validation-rmse:5.89700
# [19]	validation-rmse:5.89178
# [20]	validation-rmse:5.88957
# [21]	validation-rmse:5.89030
# [22]	validation-rmse:5.88919
# [23]	validation-rmse:5.88749
# [24]	validation-rmse:5.88489
# [25]	validation-rmse:5.88348
# [26]	validation-rmse:5.88246
# [27]	validation-rmse:5.88142
# [28]	validation-rmse:5.88031
# [29]	validation-rmse:5.87901
# [30]	validation-rmse:5.87750
# [31]	validation-rmse:5.87686
# [32]	validation-rmse:5.87600
# [33]	validation-rmse:5.87546
# [34]	validation-rmse:5.87568
# [35]	validation-rmse:5.87514
# [36]	validation-rmse:5.87047
# [37]	validation-rmse:5.87084
# [38]	validation-rmse:5.87025
# [39]	validation-rmse:5.86967
# [40]	validation-rmse:5.86995
# [41]	validation-rmse:5.86939
# [42]	validation-rmse:5.86888
# [43]	validation-rmse:5.86739
# [44]	validation-rmse:5.86667
# [45]	validation-rmse:5.86629
# [46]	validation-rmse:5.86529
# [47]	validation-rmse:5.86549
# [48]	validation-rmse:5.86514
# [49]	validation-rmse:5.86553
# [50]	validation-rmse:5.86579
# [51]	validation-rmse:5.86578
# [52]	validation-rmse:5.86298
# [53]	validation-rmse:5.86335
# [54]	validation-rmse:5.86306
# [55]	validation-rmse:5.86270
# [56]	validation-rmse:5.86289
# [57]	validation-rmse:5.86295
# [58]	validation-rmse:5.86252
# [59]	validation-rmse:5.86213
# [60]	validation-rmse:5.86089
# [61]	validation-rmse:5.86106
# [62]	validation-rmse:5.86118
# [63]	validation-rmse:5.86020
# [64]	validation-rmse:5.86040
# [65]	validation-rmse:5.86071
# [66]	validation-rmse:5.86013
# [67]	validation-rmse:5.86038
# [68]	validation-rmse:5.86044
# [69]	validation-rmse:5.86042
# [70]	validation-rmse:5.85930
# [71]	validation-rmse:5.85968
# [72]	validation-rmse:5.85948
# [73]	validation-rmse:5.85939
# [74]	validation-rmse:5.85919
# [75]	validation-rmse:5.85936
# [76]	validation-rmse:5.85918
# [77]	validation-rmse:5.86058
# [78]	validation-rmse:5.86081
# [79]	validation-rmse:5.86132
# [80]	validation-rmse:5.86143
# [81]	validation-rmse:5.86124
# [82]	validation-rmse:5.86153
# [83]	validation-rmse:5.86162
# [84]	validation-rmse:5.86205
# [85]	validation-rmse:5.86234
# [86]	validation-rmse:5.86355
# [87]	validation-rmse:5.86372
# [88]	validation-rmse:5.86413
# [89]	validation-rmse:5.86378
# [90]	validation-rmse:5.86348
# [91]	validation-rmse:5.86368
# [92]	validation-rmse:5.86441
# [93]	validation-rmse:5.86459
# [94]	validation-rmse:5.86471
# [95]	validation-rmse:5.86498
# [96]	validation-rmse:5.86488
# [97]	validation-rmse:5.86504
# [98]	validation-rmse:5.86490
# [99]	validation-rmse:5.86351
# [100]	validation-rmse:5.86341
# [101]	validation-rmse:5.86349
# [102]	validation-rmse:5.86301
# [103]	validation-rmse:5.86475
# [104]	validation-rmse:5.86421
# [105]	validation-rmse:5.86351
# [106]	validation-rmse:5.86433
# [107]	validation-rmse:5.86442
# [108]	validation-rmse:5.86473
# [109]	validation-rmse:5.86543
# [110]	validation-rmse:5.86563
# [111]	validation-rmse:5.86580
# [112]	validation-rmse:5.86579
# [113]	validation-rmse:5.86561
# [114]	validation-rmse:5.86435
# [115]	validation-rmse:5.86419
# [116]	validation-rmse:5.86387
# [117]	validation-rmse:5.86429
# [118]	validation-rmse:5.86395
# [119]	validation-rmse:5.86422
# [120]	validation-rmse:5.86379
# [121]	validation-rmse:5.86375
# [122]	validation-rmse:5.86346
# [123]	validation-rmse:5.86342
# [124]	validation-rmse:5.86289
# [125]	validation-rmse:5.86344
# [17:35:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:8.46818
# [1]	validation-rmse:6.50458
# [2]	validation-rmse:6.12153
# [3]	validation-rmse:6.03688
# [4]	validation-rmse:6.00749
# [5]	validation-rmse:5.99988
# [6]	validation-rmse:5.99365
# [7]	validation-rmse:5.98773
# [8]	validation-rmse:5.98163
# [9]	validation-rmse:5.97946
# [10]	validation-rmse:5.97210
# [11]	validation-rmse:5.96970
# [12]	validation-rmse:5.96944
# [13]	validation-rmse:5.96941
# [14]	validation-rmse:5.96754
# [15]	validation-rmse:5.96471
# [16]	validation-rmse:5.96001
# [17]	validation-rmse:5.95641
# [18]	validation-rmse:5.94974
# [19]	validation-rmse:5.94645
# [20]	validation-rmse:5.94533
# [21]	validation-rmse:5.94120
# [22]	validation-rmse:5.93796
# [23]	validation-rmse:5.92685
# [24]	validation-rmse:5.92530
# [25]	validation-rmse:5.92486
# [26]	validation-rmse:5.92400
# [27]	validation-rmse:5.91727
# [28]	validation-rmse:5.91690
# [29]	validation-rmse:5.91521
# [30]	validation-rmse:5.91408
# [31]	validation-rmse:5.91271
# [32]	validation-rmse:5.91202
# [33]	validation-rmse:5.91296
# [34]	validation-rmse:5.91280
# [35]	validation-rmse:5.91104
# [36]	validation-rmse:5.91083
# [37]	validation-rmse:5.90936
# [38]	validation-rmse:5.90872
# [39]	validation-rmse:5.90784
# [40]	validation-rmse:5.90586
# [41]	validation-rmse:5.90532
# [42]	validation-rmse:5.90013
# [43]	validation-rmse:5.89969
# [44]	validation-rmse:5.89568
# [45]	validation-rmse:5.89776
# [46]	validation-rmse:5.89762
# [47]	validation-rmse:5.89556
# [48]	validation-rmse:5.89758
# [49]	validation-rmse:5.89525
# [50]	validation-rmse:5.89357
# [51]	validation-rmse:5.89444
# [52]	validation-rmse:5.89331
# [53]	validation-rmse:5.89265
# [54]	validation-rmse:5.89180
# [55]	validation-rmse:5.88978
# [56]	validation-rmse:5.89060
# [57]	validation-rmse:5.89017
# [58]	validation-rmse:5.88921
# [59]	validation-rmse:5.88937
# [60]	validation-rmse:5.88924
# [61]	validation-rmse:5.88903
# [62]	validation-rmse:5.88900
# [63]	validation-rmse:5.87697
# [64]	validation-rmse:5.87723
# [65]	validation-rmse:5.87822
# [66]	validation-rmse:5.87821
# [67]	validation-rmse:5.87359
# [68]	validation-rmse:5.87312
# [69]	validation-rmse:5.86784
# [70]	validation-rmse:5.86784
# [71]	validation-rmse:5.86824
# [72]	validation-rmse:5.86632
# [73]	validation-rmse:5.86649
# [74]	validation-rmse:5.86697
# [75]	validation-rmse:5.86600
# [76]	validation-rmse:5.86511
# [77]	validation-rmse:5.86526
# [78]	validation-rmse:5.86531
# [79]	validation-rmse:5.86537
# [80]	validation-rmse:5.86562
# [81]	validation-rmse:5.86662
# [82]	validation-rmse:5.86623
# [83]	validation-rmse:5.86674
# [84]	validation-rmse:5.86736
# [85]	validation-rmse:5.86706
# [86]	validation-rmse:5.86609
# [87]	validation-rmse:5.86570
# [88]	validation-rmse:5.86829
# [89]	validation-rmse:5.86870
# [90]	validation-rmse:5.86736
# [91]	validation-rmse:5.86626
# [92]	validation-rmse:5.86590
# [93]	validation-rmse:5.86485
# [94]	validation-rmse:5.86361
# [95]	validation-rmse:5.86397
# [96]	validation-rmse:5.86404
# [97]	validation-rmse:5.86409
# [98]	validation-rmse:5.86388
# [99]	validation-rmse:5.86273
# [100]	validation-rmse:5.86144
# [101]	validation-rmse:5.86028
# [102]	validation-rmse:5.86021
# [103]	validation-rmse:5.86110
# [104]	validation-rmse:5.86089
# [105]	validation-rmse:5.86169
# [106]	validation-rmse:5.86184
# [107]	validation-rmse:5.86315
# [108]	validation-rmse:5.86451
# [109]	validation-rmse:5.86509
# [110]	validation-rmse:5.86631
# [111]	validation-rmse:5.86642
# [112]	validation-rmse:5.86740
# [113]	validation-rmse:5.86889
# [114]	validation-rmse:5.86987
# [115]	validation-rmse:5.87624
# [116]	validation-rmse:5.87533
# [117]	validation-rmse:5.87448
# [118]	validation-rmse:5.87267
# [119]	validation-rmse:5.87391
# [120]	validation-rmse:5.87442
# [121]	validation-rmse:5.87466
# [122]	validation-rmse:5.87424
# [123]	validation-rmse:5.87573
# [124]	validation-rmse:5.87577
# [125]	validation-rmse:5.87637
# [126]	validation-rmse:5.87638
# [127]	validation-rmse:5.87634
# [128]	validation-rmse:5.87542
# [129]	validation-rmse:5.87574
# [130]	validation-rmse:5.87513
# [131]	validation-rmse:5.87512
# [132]	validation-rmse:5.87598
# [133]	validation-rmse:5.87659
# [134]	validation-rmse:5.87610
# [135]	validation-rmse:5.87594
# [136]	validation-rmse:5.87655
# [137]	validation-rmse:5.87617
# [138]	validation-rmse:5.87603
# [139]	validation-rmse:5.87680
# [140]	validation-rmse:5.87752
# [141]	validation-rmse:5.87870
# [142]	validation-rmse:5.87893
# [143]	validation-rmse:5.87972
# [144]	validation-rmse:5.87988
# [145]	validation-rmse:5.87809
# [146]	validation-rmse:5.87874
# [147]	validation-rmse:5.87945
# [148]	validation-rmse:5.87971
# [149]	validation-rmse:5.87945
# [150]	validation-rmse:5.88092
# [151]	validation-rmse:5.88091
# 100%|██████████| 2/2 [00:19<00:00,  9.74s/trial, best loss: 5.863677389008578]

# %%
best_result['max_depth'] = int(best_result['max_depth'])
best_result
# Out:
# {'learning_rate': 0.2869399796159504,
#  'max_depth': 41,
#  'min_child_weight': 2.4402463748440546,
#  'reg_alpha': 0.1903743627973874,
#  'reg_lambda': 0.021810187745469563}

# %%
booster = xgb.train(
            params=best_result,
            dtrain=train,
            num_boost_round=40,
            evals=[(valid, 'validation')],
            early_stopping_rounds=5
)

y_pred = booster.predict(valid)
rmse = mean_squared_error(y_val, y_pred, squared=False)

#with open("models/preprocessor.b", "wb") as f_out:
    #pickle.dump(dv, f_out)
# Out:
# [0]	validation-rmse:13.32455
# [1]	validation-rmse:10.56704
# [2]	validation-rmse:8.77074
# [3]	validation-rmse:7.64520
# [4]	validation-rmse:6.96657
# [5]	validation-rmse:6.56435
# [6]	validation-rmse:6.31657
# [7]	validation-rmse:6.16921
# [8]	validation-rmse:6.08078
# [9]	validation-rmse:6.02255
# [10]	validation-rmse:5.98528
# [11]	validation-rmse:5.95589
# [12]	validation-rmse:5.93622
# [13]	validation-rmse:5.92320
# [14]	validation-rmse:5.91438
# [15]	validation-rmse:5.90859
# [16]	validation-rmse:5.90467
# [17]	validation-rmse:5.90137
# [18]	validation-rmse:5.89700
# [19]	validation-rmse:5.89178
# [20]	validation-rmse:5.88957
# [21]	validation-rmse:5.89030
# [22]	validation-rmse:5.88919
# [23]	validation-rmse:5.88749
# [24]	validation-rmse:5.88489
# [25]	validation-rmse:5.88348
# [26]	validation-rmse:5.88246
# [27]	validation-rmse:5.88142
# [28]	validation-rmse:5.88031
# [29]	validation-rmse:5.87901
# [30]	validation-rmse:5.87750
# [31]	validation-rmse:5.87686
# [32]	validation-rmse:5.87600
# [33]	validation-rmse:5.87546
# [34]	validation-rmse:5.87568
# [35]	validation-rmse:5.87514
# [36]	validation-rmse:5.87047
# [37]	validation-rmse:5.87084
# [38]	validation-rmse:5.87025
# [39]	validation-rmse:5.86967

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()
# Out:
# /var/folders/lx/m3fc9q_96bq7m1wyg7w6s1pc0000gn/T/ipykernel_5864/1672306066.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction')
# /var/folders/lx/m3fc9q_96bq7m1wyg7w6s1pc0000gn/T/ipykernel_5864/1672306066.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, label='actual')
